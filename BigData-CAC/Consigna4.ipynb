# %% [markdown]
# ### <font color='cian'>ENTREGA DE LA CONSIGNA #4 </font>
#
# * NOMBRE: <font color='cian'>Maria Belen Areal</font>
# * DNI: <font color='cian'>35.367.971</font>
# * COMISIÓN: <font color='cian'>23678CaC - Big Data /Data Anlaytics</font>
#
# <font color='cian'>Archivos complementarios en FILES > Mi Proyecto > c23678-MariaBelenAreal-TPIntegrador</font>

# %% [markdown]
# <font color='cian'>
# ________________________________________________________
# 1. GOOGLE SHEETS </font>

# %% [markdown]
# <font color='cian'>2. Cargué, renombre el csv en googles sheets. Luego edité las columnas indicadas.
# Para los dos últimos puntos utilice los siguientes códigos:</font>
# - Género: =ARRAYFORMULA(iferror(ifs(REGEXMATCH(P2;"ACTOR");"Masculino"; REGEXMATCH(P2;"ACTOR IN A LEADING ROLE");"Masculino"; REGEXMATCH(P2;"ACTOR IN A SUPPORTING ROLE");"Masculino"; REGEXMATCH(P2;"ACTRESS");"Femenino"; REGEXMATCH(P2;"ACTREES IN A LEADING ROLE");"Femenino"; REGEXMATCH(P2;"ACTRESS IN A SUPPORTING ROLE");"Femenino")))
#
# - Taquilla_presupuesto: =ARRAYFORMULA(IFERROR(IFS(W2/V2<=1; "Fracaso";W2/V2<=5; "Regular";W2/V2<=15; "Buena";W2/V2<=25; "Éxito";W2/V2<=50; "Éxitazo";W2/V2>50; "Genios Totales")))

# %% [markdown]
# <font color='cian'>3. Realice todos los ítems (en Mi proyecto se encuentran las capturas) salvo el E), porque la querry no me funcionó para realizar la consulta.</font>
#
# /work/Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_01.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_02.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_03.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_04.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_05.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_06.png" width="" align="" />

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_07.png" width="" align="" />

# %% [markdown]
# <font color='cian'>4. Link al sheets de google</font>
# https://docs.google.com/spreadsheets/d/1apUH0RKDmnQ21s1ijeMQ6yGTSxSMSopraRL8JGsdHbg/edit?usp=sharing

# %% [markdown]
# <font color='cian'>5. No realizado</font>

# %% [markdown]
# <font color='cian'>
# ________________________________________________________
# 1. LOOKER STUDIO </font>

# %% [markdown]
# <font color='cian'>2. Generé el archivo en Looker Studio y lo enlace al google sheet usado anteriormente. </font>

# %% [markdown]
# <font color='cian'>3. Tengo un error al cargar el mapa en el ítem H), lo cargué como mapa de calor que fue el único que logré visualizar correctamente. Adjunto captura de la configuración en la carpeta Mi proyecto. El resto de los ítems fueron realizados. </font>
#
# /work/Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4

# %% [markdown]
# <img src="Mi proyecto/c23678-MariaBelen-Areal-TPintegrador/Consigna #4/consigna4_lookerstudio_completo.png" width="" align="" />

# %% [markdown]
# <font color='cian'>4. Link al Looker Studio:</font>
# https://lookerstudio.google.com/reporting/16cc4ec2-e2f2-4917-b7b3-ba5b57e4ba79

# %% [markdown]
# <font color='cian'>5. No realizado</font>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=da85ffec-f3f8-46e6-a8a8-28433ab3181c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
