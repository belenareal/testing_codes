# %% [markdown]
# ### <font color='cian'>ENTREGA DE LA CONSIGNA #2 </font>
#
# * NOMBRE: <font color='cian'>Maria Belen Areal</font>
# * DNI: <font color='cian'>35.367.971</font>
# * COMISIÓN: <font color='cian'>23678CaC - Big Data /Data Anlaytics</font>
#
# <font color='cian'>Archivos complementarios en FILES > Mi Proyecto > c23678-MariaBelenAreal-TPIntegrador. Ahí se encuentran las capturas de pantalla y archivos .sql</font>
#
# ----------------------------------------

# %% [markdown]
# # Consignas #4:
# ---
#
# **A.** Debes estar registrado en [Looker studio](https://lookerstudio.google.com/overview).
#
# **B. Contexto**
#
# Extrajimos algunas columnas de las tablas de la BBDD netflix para crear un archivo de tipo csv: **<font color='red'>set_total.csv</font>**.
#
# **C. Recordá que:**
#
# 1. Los ejercicios marcados como **"Desafíos"** son optativos, <u>de entrega no obligatoria</u> pero contribuyen a tu ejercitación como profesional.
# 1. Los enunciados contienen indicaciones mínimas que puedes mejorar. Sé creativo y piensa como si ya fueses un profesional de los datos.
# 1. El trabajo final es TU PORTAFOLIO. Tenelo presente y enriquecelo con tus propios aportes.
# 1. Por otra parte si quieres entender mejor el tipo de gráficas y sus usos, puedes revisar el sigiuente link: [Catálogo de visualizaciones](https://datavizcatalogue.com/ES/)
#
# Recordá mantener actualizado tu Deepnote.
#
# ### ¡Mucho éxitos y a seguir!

# %% [markdown]
# # Actividades

# %% [markdown]
# ## 1. Planillas de cáclulo - Google Sheets
#
# Entre el **20/09/2023** hasta el **08/10/2023**, se deben cubrir los siguientes objetivos:
#
# 1.- Descargar el archivo csv compartido e importalo en una hoja de cálculo de Google, donde lo analizarás de forma global, para luego realizar análisis más específicos y crear visualizaciones simples para los datos.

# %% [markdown]
# 2. Revisión, adecuación y limpieza de csv:
#     + Crear una planilla de cálculo en Google Sheets y nombrarla **<font color='red'>set_total</font>**. Nombrar **<font color='red'>data</font>** a la hoja principal de la planilla.
#     + Buscar registros duplicados y eliminarlos.
#     + Chequear el formato de los datos (numérico en las columnas en que deba haber números, texto en las columnas correspondientes, etc.)
#     + Separar la columna "duration" en dos: en "duration" deben quedar solo los números, mientras que la que quede con los textos deben llamarla "tiempo_temporadas".
#     + Crear una columna a la izquierda de la columna "title_oscar" y titularla "género". Indicar "Femenino" o "Masculino" en los registros que tienen como categorias ACTOR, ACTOR IN A LEADING ROLE, ACTOR IN A SUPPORTING ROLE, ACTRESS, ACTRESS IN A LEADING ROLE, ACTRESS IN A SUPPORTING ROLE, según corresponda. (Dejar vacía si no se corresponde las categorias mencionadas). **<font color='blue'>¡Tip: la combinación de las siguientes funciones puede ser útil: ARRAY_CONSTRAIN, ARRAYFORMULA, SI, REGXMATCH y/o SI.ERROR!</font>**
#     + Crear una columna que se complete con un valor en función de la relación entre taquilla (box_office_x_millon) y presupuesto (budget_x_million) de las películas.
#         si es menor o igual a 1:  `Fracaso`
#         si es menor o igual a 5: `Regular`
#         si es menor o igual a 15: `Buena`
#         si es menor o igual a 25: `Éxito`
#         si es menor o igual a 50: `Éxitazo`
#         si es mayor a 50: `Genios Totales`
# **<font color='blue'>¡Tip: la combinación de las siguientes funciones puede ser útil: ARRAY_CONSTRAIN, ARRAYFORMULA, SI, LET y/o SI.ERROR!</font>**

# %% [markdown]
# 3. Realizar cada una de las siguientes consignas en una hoja de la planilla **<font color='red'>set_total</font>**, nombrando cada hoja según la consigna indique. Titular los gráficos de manera adecuada y agregar las etiquetas de los datos y leyendas, **<font color='blue'>¡Tip: los intervalos con nombres te pueden falcilitar el trabajo!</font>**:
#
#     <b>A.</b> Realizar un gráfico (hoja **Gráfico 1**) que muestre la relación entre la cantidad de series y películas disponibles en Netflix.
#
#     <b>B.</b> Construir una tabla dinámica (hoja **Tabla dinámica 1**) que muestre de manera descendente los 15 países que tienen mayor cantidad total de títulos en la plataforma, desglosando por tipo de contenido.
#
#     <b>C.</b> Realizar una gráfico (hoja **Gráfico 2**) a partir de la tabla dinámica del punto anterior, mostrando la información sólo para los primeros 10 países (mostrar el desglose por tipo de contenido).
#
#     <b>D.</b> Construir una tabla dinámica (hoja **Tabla dinámica 2**) que muestre el nombre de las películas nominadas, el año de la ceremonia correspondiente y la cantidad de oscar ganados (Winner = 1). Agregar una métrica/valor calculado para mostrar la relación entre nominaciones y estatuillas ganadas, utilizando para ello la formula  `=CONTAR.SI(winner;"=1")/CONTARA(winner)` (establecer la opción "Personalizado" para la Configuración "Sumar por"). Dejar la tabla dinámica organizada de mayor a menor por esta columna calculada.
#
#     <b>E.</b> Crear una tabla (hoja **Tabla 1**) para mostrar los datos de la tabla dinámica del punto anterior, limitada sólo a las 4 películas de mejor perfomance en los oscar. **<font color='blue'>¡Tip: si realizaste bien la tabla dinámica, basta con utilizar la función Query para resolver este punto. (hay otras fórmulas que te permitirán llegar al mismo resultado)!</font>**
#
#     <b>F.</b> Contruir una tabla dinámica (hoja **Tabla dinámica 3**)  que muestre la cantidad total de títulos estrenados por año, mostrando también cuántos son películas y cuántas series. Ordenar cronológicamente, comenzando por el más actual.

# %% [markdown]
# 4. <b>¿Qué debo hacer en Deepnote? </b>
#     * Realizar una breve descripción de los resultados de tu revisión (punto 2), remarcando resultados llamativos, inconvenientes, fórmulas utilizadas o cualquier otra cosa que se te ocurra. (Se puede y se sugiere apoyarse con imágenes).
#     * Insertar **<font color='blue'>El link</font>** de la planilla de Google <B><font color='red'>set_total</font></B>
#     * Subir/insertar imágenes que demuestren el cumplimiento de las consignas del punto 3. <B><font color='blue'>¡Tip: investigá la opción "Publicar Gráfico" en Google Sheet para insertar directamente la imagen en Deepnote con un codigo iframe,con el que podés definir la altura y ancho a mostrar (width="700" height="400").

# %% [markdown]
# 5. <font color='green'>**DESAFIOS**</font>:
#     Completá las siguientes consignas en la Hojas de Cálculo. No olvides los detalles, como las etiquetas de los datos, nombres de los ejes y títulos. Organiza tus Hojas de Cálculo poniéndole nombre a los intervalos de datos y a las hojas.
#     Diseña una gráfica:
#     <b>I.</b> A partir de la tabla dinámica del punto F crear un gráfico (hoja **Gráfico A**) que muestre el top 10 de años donde se realizaron más lanzamientos, desglosando por tipo de contenido(Movie o Tv Show)**<font color='blue'> Tip: Puede ser que necesites una tabla intermedia para ordenar los datos</font>**.
#     <b>II.</b>  de líneas a partir de la tabla dinámica obtenida en el punto F (hoja **Gráfico B**), y debe mostrar cantidad de títulos estrenados a partir del año 2008 (hasta la actualidad) discriminando por tipo de contenido.
#     <b>III.</b> de barras apiladas a partir de la tabla dinámica obtenida en el punto F (hoja **Gráfico B**), que debe mostrar los mismos datos y criterios que el punto anterior.
#     <b>IV.</b> Respecto a los dos puntos anteriores y en pocas líneas: ¿creés que ambas gráficas dan la misma información? ¿Se te ocurren soluciones alternativas para mejorarlas?
#     <b>IV.</b>  Construí una tabla dinámica (hoja **Tabla dinámica A**) que muestre la relación entre el género del  actor/actriz y la cantidad de nominaciones y oscars ganados:
#     - Creá un campo calculado (Campo calculado 1) que evaluará los cantidad de premios oscar obtenidos.
#     - Creá otro campo calculado (Campo calculado 2) para encontrar la cantidad de nominaciones a los premios oscar. En cada campo calculado en "sumar por" configúralo como "Personalizado". Organizalo de mayor a menor por la columna de nominaciones. **<font color='blue'>Tip: el punto 3D te puede ayudar.</font>**
#     <b>V.</b> En relación a la tabla dinámica obtenida en el punto anterior, planteá una solución diferente para llegar al Campo calculado 2 sin hacerlo por un campo calculado sino por una campo de los que ya existen directamente.
#     <b>VI.</b> En relación a la tabla dinámica obtenida en el punto IV, diseñá una tabla, hoja **Tabla A**, que muestre sólo las actrices/actores que:
#     * Hayan sido nominados solo 2 veces y que hayan obtenido esos dos premios.
#     * Hayan sido nominado más de dos veces.
#     * Ordenalos por mayor cantidad de nominaciones, luego por mayor cantidad de victorias y luego alfabéticamente por el nombre.

# %% [markdown]
# ## 2.- Crear un informe de visualización desde Looker Studio
#
# 1. Conectar la hoja **<font color='red'>Data</font>** del archivo **<font color='red'>set_total</font>**  a Looker Studio:
#     * Nombrá a tu informe en Looker de la siguiente forma: **c236XX-nombre-apellido-TPintegrador**.
#     * Recordá que podés darle estilo y diseño para hacerlo más vistoso, llamativo y organizado.
#     * Analizá las consignas para que los datos que conectes sean suficientes **<font color='blue'>¡Posiblemente no necesites usar todas las columnas!</font>**

# %% [markdown]
# 2. Revisar que los datos se correspondan con el tipo de dato adecuado según las definiciones propias de Looker Studio (Fechas, Texto, Año, País, Porcentaje, Duración, Ciudad, etc.) Modificar el tipo de dato si corresponde.

# %% [markdown]
# 3. Realizar las siguientes consignas, teniendo en cuenta los datos, las etiquetas, leyendas y títulos según sea posible. Acomodá las visualizaciones como consideres conveniente para que tu informe quede organizado y con un diseño atractivo. **<font color='blue'>¡Importante! La fuente de datos tiene muchos registros de tipo nulo, utilizá recursos como filtros para que no perjudiquen las visualizaciones!</font>**:
#
#     <b>H.</b> Construir un mapa coroplético que muestre la cantidad títulos (series y movies) por país. No tomes en cuenta las colaboraciones entre varios países, sólo títulos que los que produce un único país.
#
#     <b>I.</b> Construir un gráfico que muestre de forma descendente el top 20 de directores con más producciones. Incluir un control que permita filtrar por los tipos de títulos (Movie-TvShow).
#
#     <b>J.</b> Construir un gráfico que muestre de forma descendente los 10 géneros de Netflix con mayor cantidad de producciones.
#
#     <b>K.</b> Construir un gráfico que muestre de forma descendente el top 10 de clasificaciones por público (rating) desglosando por tipo de contenido.
#
#     <b>L.</b> Construir un gráfico que muestre de forma ascendente las 20 películas o series más antiguas.
#
#     <b>M.</b> Construir un gráfico que muestre de forma ascendente los 15 idiomas de películas con mayor cantidad de títulos, sin contar inglés.

# %% [markdown]
# 4. **<b>¿Qué debo hacer en Deepnote?:</b>**
#     * Insertar el **<font color='blue'>link</font>** de tu informe en Looker Studio.

# %% [markdown]
# 5. <font color='green'>**DESAFÍOS**</font>:
#     Completá las siguientes consignas en Looker Studio. No olvides los detalles, como las etiquetas de los datos, nombres de los ejes y títulos. Colocalos como sea más conveniente para hacer que el diseño de tu informe sea más atractivo. **<font color='blue'>¡Considerá que hay muchos registros nulos. Utilizá filtros para mejorar la visualización de tus datos!.</font>**
#     Graficá en Looker Studio:
#     <b>I.</b> El punto 3.A.
#     <b>II.</b> El punto 3.C.
#     <b>III.</b> El punto 5.I.
#     <b>IV.</b> El punto 5.II.
#     <b>V.</b> El punto 5.III.
#     <b>VI.</b> Construye un gráfico de rectángulos que muestre un top 10 de la duración con respecto a sus cantidades separados por los tipos. que existen. Incluye un control que permita filtrar por los tipos para mostrar mayor cantidad parcial dependiendo del seleccionado. Organizado siempre por mayor cantidad total de forma descendente.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9df67157-660d-4a27-9fa6-7a0b53ffc7a7' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
